# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read data
url = 'https://raw.githubusercontent.com/nghiale0811/Practice-Datasets/main/avocado.csv'
dataset = pd.read_csv(url)

# %% [markdown]
# #EDA

# %%
#show first 5 rows of the dataset
dataset.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
dataset.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
dataset.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
dataset.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
print(f"Rows number: {dataset.shape[0]}")
print(f"Columns number: {dataset.shape[1]}")
# Out:
# Rows number: 18249
# Columns number: 14

# %%
#Price distribution
plt.figure(figsize=(12,5))
plt.title("Distribution Price")
ax = sns.distplot(dataset["AveragePrice"], color = 'r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(y="type", x="AveragePrice", data=dataset, palette = 'pink')

# %%
# Year with the major number of bags
bags_per_year = dataset['Total Bags'].ne(0).groupby(dataset['year']).sum() / len(dataset) * 100
bags_per_year
# Out:
# year
# 2015    30.686613
# 2016    30.774289
# 2017    31.355143
# 2018     7.101759
# Name: Total Bags, dtype: float64

# %%
# plotting the data
years = ['2015', '2016', '2017', '2018']
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.bar(years, bags_per_year)
ax.set_title('Percentage of sold bags per year')
ax.set_xlabel('Years')
ax.set_ylabel('Sales in %')
# Out:
# Text(0, 0.5, 'Sales in %')

# %%
# Correlation between target and a selected feature(Numerical)
def correlation(df, target, feature):
    corr = df[[target, feature]].corr()[feature][0]
    
    fig, ax = plt.subplots(figsize=(12, 7))
    sns.set_theme(style='dark')
    sns.scatterplot(data=df, x=feature, y=target)
    ax.set_title(f"Correlation between {target} and {feature} is: {round(corr, 3)}")

# %%
correlation(dataset, 'AveragePrice', 'Total Volume')

# %%
correlation(dataset, 'AveragePrice', 'Total Bags')

# %%
# Heatmap
corr = dataset.corr()
plt.figure(figsize=(12,7))
sns.heatmap(
    data=corr, 
    cmap='plasma', 
    annot=True, 
    linewidths=0.25, 
    linecolor='black', 
    annot_kws={'size': 10}
)

# %% [markdown]
# #Data cleaning

# %%
dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# #Check for skewness

# %%
from scipy.stats import norm
plt.figure(figsize=(12, 7))
sns.set_theme(style='darkgrid')
sns.distplot(dataset['AveragePrice'], kde=True, fit=norm)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #Check for outliers

# %%
# using seaborn boxplot to identify outliers
plt.figure(figsize=(12, 7))
sns.boxplot(data=dataset['AveragePrice'])

# %%
# removing outliers
mean = np.mean(dataset['AveragePrice'])
sigma = np.std(dataset['AveragePrice']) 
lower_range = mean - (3 * sigma)
upper_range = mean + (3 * sigma)
print(f"Data between {lower_range} and {upper_range} should be considered good data")
# Out:
# Data between 0.1979818422594828 and 2.6139749772922825 should be considered good data

# %%
# number of outliers
outliers = [outlier for outlier in dataset['AveragePrice'] if outlier < lower_range or outlier > upper_range]
print(f"Outliers found: {len(outliers)}")
# Out:
# Outliers found: 131

# %% [markdown]
# #Data Preprocessing

# %%
df = dataset[(dataset['AveragePrice'] > lower_range) & (dataset['AveragePrice'] < upper_range)]

# %% [markdown]
# Now we would run a regression model on our data

# %%
df = df.drop('Date', axis=1)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5677.40      133.76          0.0  conventional  2015  Albany
# 4     5986.26      197.69          0.0  conventional  2015  Albany

# %%
y = df['AveragePrice']
X = df.drop('AveragePrice', axis = 1)
X.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags          type  year  region
# 0       93.25          0.0  conventional  2015  Albany
# 1       97.49          0.0  conventional  2015  Albany
# 2      103.14          0.0  conventional  2015  Albany
# 3      133.76          0.0  conventional  2015  Albany
# 4      197.69          0.0  conventional  2015  Albany

# %%
y.head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
#Apply ordinal encoder (i.e categorical values into integers)
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
oe.fit([X['region']])
X['region'] = oe.fit_transform(X[['region']])

# %%
X.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags          type  year  region
# 0       93.25          0.0  conventional  2015     0.0
# 1       97.49          0.0  conventional  2015     0.0
# 2      103.14          0.0  conventional  2015     0.0
# 3      133.76          0.0  conventional  2015     0.0
# 4      197.69          0.0  conventional  2015     0.0

# %%
# working on 'type' column
oe.fit(X[['type']])
X['type'] = oe.fit_transform(X[['type']])

# %%
X.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags  type  year  region
# 0       93.25          0.0   0.0  2015     0.0
# 1       97.49          0.0   0.0  2015     0.0
# 2      103.14          0.0   0.0  2015     0.0
# 3      133.76          0.0   0.0  2015     0.0
# 4      197.69          0.0   0.0  2015     0.0

# %% [markdown]
# #Train Test Split

# %%
from sklearn.model_selection import train_test_split

# splitting the dataset into train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=None)

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# training the model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# making predictions
prediction = lr.predict(X_test)
print(prediction)
# Out:
# [1.63643238 1.16072966 1.1769348  ... 1.29829528 1.70973229 1.63025594]

# %%
# Mean absolute percentage error
def mape(y_test, prediction):
    y_test = np.array(y_test)
    prediction = np.array(prediction)
    return np.mean(np.abs((y_test - prediction) / y_test)) * 100

# %%
print(f"Mean Absolute Error: {mean_absolute_error(y_test, prediction)}")
print(f"Mean Absolute Percentage Error: {mape(y_test, prediction)}")
print(f"Accuracy: {100 - mape(y_test, prediction)}")
# Out:
# Mean Absolute Error: 0.23207049916107603
# Mean Absolute Percentage Error: 17.958237834283846
# Accuracy: 82.04176216571615
